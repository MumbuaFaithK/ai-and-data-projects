# %% [markdown]
# <a href="https://colab.research.google.com/github/MumbuaFaithK/ai-and-data-projects/blob/main/datascraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Web Scraping Project by Faith Mumbua

# %%
...
#Title: webscraping Project
#Name: Faith Mumbua
#Date: 17/May/2025
...
#importing libraries i will need for webscraping
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#set URL of website in a variable
url = 'https://www.scrapethissite.com/pages/forms/'
page = requests.get(url)

# %%
#parse html
soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
#Extract the table with the Hockey Scores
hockey_table = soup.find('table', class_='table')
print(hockey_table)
# Out:
# <table class="table">
# <tr>
# <th>
#                             Team Name
#                         </th>
# <th>
#                             Year
#                         </th>
# <th>
#                             Wins
#                         </th>
# <th>
#                             Losses
#                         </th>
# <th>
#                             OT Losses
#                         </th>
# <th>
#                             Win %
#                         </th>
# <th>
#                             Goals For (GF)
#                         </th>
# <th>
#                             Goals Against (GA)
#                         </th>
# <th>
#                             + / -
#                         </th>
# </tr>
# <tr class="team">
# <td class="name">
#                             Boston Bruins
#                         </td>
# <td class="year">
#                             1990
#                         </td>
# <td class="wins">
#                             44
# ...

# %%
#Extract the column headings
table_titles = hockey_table.find_all('th')
hockey_table_title = [title.text.strip() for title in table_titles]
print(hockey_table_title)
# Out:
# ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']

# %%
#Save the column headings onto a Pandas DataFrame
df = pd.DataFrame(columns=hockey_table_title)
df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %%
#Create an empty list to hold all team data
all_teams = []

# %%
#Find all team rows
teams = soup.find_all('tr', class_='team')
for title in teams:
  print(title.text.strip())
# Out:
# Boston Bruins
#
#
#                             1990
#
#
#                             44
#
#
#                             24
#
#
#
#
#                             0.55
#
#
#                             299
#
#
#                             264
#
#
#                             35
# Buffalo Sabres
#
#
#                             1990
#
#
#                             31
#
#
#                             30
#
#
#
#
#                             0.388
#
#
#                             292
#
#
#                             278
#
#
#                             14
# Calgary Flames
#
#
#                             1990
#
#
#                             46
#
#
#                             26
#
#
#
#
#                             0.575
#
#
#                             344
#
#
#                             263
#
#
#                             81
# Chicago Blackhawks
#
#
#                             1990
#
#
#                             49
#
#
#                             23
#
#
#
# ...

# %%
#Extract data for each team
for team in teams:
        name = team.find('td', class_='name').text.strip()
        year = int(team.find('td', class_='year').text.strip())
        wins = int(team.find('td', class_='wins').text.strip())
        losses = int(team.find('td', class_='losses').text.strip())
        print({
    "Name": name,
    "Year": year,
    "Wins": wins,
    "Losses": losses
})
# Out:
# {'Name': 'Boston Bruins', 'Year': 1990, 'Wins': 44, 'Losses': 24}
# {'Name': 'Buffalo Sabres', 'Year': 1990, 'Wins': 31, 'Losses': 30}
# {'Name': 'Calgary Flames', 'Year': 1990, 'Wins': 46, 'Losses': 26}
# {'Name': 'Chicago Blackhawks', 'Year': 1990, 'Wins': 49, 'Losses': 23}
# {'Name': 'Detroit Red Wings', 'Year': 1990, 'Wins': 34, 'Losses': 38}
# {'Name': 'Edmonton Oilers', 'Year': 1990, 'Wins': 37, 'Losses': 37}
# {'Name': 'Hartford Whalers', 'Year': 1990, 'Wins': 31, 'Losses': 38}
# {'Name': 'Los Angeles Kings', 'Year': 1990, 'Wins': 46, 'Losses': 24}
# {'Name': 'Minnesota North Stars', 'Year': 1990, 'Wins': 27, 'Losses': 39}
# {'Name': 'Montreal Canadiens', 'Year': 1990, 'Wins': 39, 'Losses': 30}
# {'Name': 'New Jersey Devils', 'Year': 1990, 'Wins': 32, 'Losses': 33}
# {'Name': 'New York Islanders', 'Year': 1990, 'Wins': 25, 'Losses': 45}
# {'Name': 'New York Rangers', 'Year': 1990, 'Wins': 36, 'Losses': 31}
# ...

# %%
#Append to list as a dictionary
all_teams.append({
            'Team': name,
            'Year': year,
            'Wins': wins,
            'Losses': losses,
            'OT Losses': ot_losses,
            'Win %': pct,
            'Goals For': goals_for,
            'Goals Against': goals_against,
            'Goal Diff': diff
        })
#Create DataFrame from the list of dictionaries
df = pd.DataFrame(all_teams)
#Preview the data
print(df.head())
# Out:
#                  Team  Year  Wins  Losses  OT Losses  Win %  Goals For  \
# 0  Chicago Blackhawks  1991    36      29        NaN    NaN        NaN
# 1  Chicago Blackhawks  1991    36      29        NaN    NaN        NaN
# 2  Chicago Blackhawks  1991    36      29        NaN    NaN        NaN
# 3  Chicago Blackhawks  1991    36      29        0.0   0.45      257.0
# 4  Chicago Blackhawks  1991    36      29        0.0   0.45      257.0
#
#    Goals Against  Goal Diff
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3          236.0       21.0
# 4          236.0       21.0

# %%
#Export to CSV file
df.to_csv('hockey_teams_data.csv', index=False)
print("Data exported to 'hockey_teams_data.csv'")
# Out:
# Data exported to 'hockey_teams_data.csv'
